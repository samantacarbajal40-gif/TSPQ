# %% [markdown]
# # Notas
#
# Las graficas son herramientas de la estadística descriptiva, para organizar, resumir y describir un conjunto de datos sin hacer inferencias o predicciones.
#
#
# *   **Histograma:** es una gráfica de barras que representan la frecuencia con la que aparecen los valores de una variables cuantitativa. Se utiliza cuando quieres conocer cómo de distribuyen los datos
#
# *  **Caja o  caja de gato:** Es una gráfica que resume la distribución de los datos mediante la media, cuartiles, los valores mínimo y máximos , y los posibles valores atípicos. Se utiliza para resumir la distribución de los datos o comparar dps o más grupos.

# %% [markdown]
# # Análisis Estadístico
#
#  En python un IFrame es un componente para mostrar contenido web o archivos HTML dentro de un cuaderno de Google colab.
#
#
# *   Se utiliza para incrustar una página web, un archvo HTML o un documenti PDF dentro de la salida de notebook, sin necsidad de abrir otra ventana del navegador.

# %%
from IPython.display import IFrame

pdf_url = "https://raw.githubusercontent.com/marinlopabi/Temas_Selectos_PQ_26-I/refs/heads/main/Datos-IQ-Esta.pdf"
viewer = "https://drive.google.com/viewerng/viewer?embedded=true&url=" + pdf_url

IFrame(viewer, width=1000, height=900) # No se encuentra el archivo en la carpeta de esta clase por eso tal vez no se observa nada
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="https://drive.google.com/viewerng/viewer?embedded=true&url=https://raw.githubusercontent.com/marinlopabi/Temas_Selectos_PQ_26-I/refs/heads/main/Datos-IQ-Esta.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Ejercicio
#
# Columna de destilación generada a partir de un modelo matemático. Se han añadido características de datos atípicos, como ruido, valores atípicos y datos faltantes, para obtener las condiciones industriales en el conjunto de datos.
#
# Se cuenta con 450 horas de operación con un muestreo de 0.1 horas.
#
# Este conjunto de datos se ha utilizado para la validación de sensores suaves y la validación de un nuevo algoritmo de selección de características.
#
# Referencia: Cote-Ballesteros, J. E., Grisales Palacios, V. H., y Rodriguez-Castellanos, J. E. (2022). Un algoritmo de selección de variables de enfoque híbrido basado en información mutua para aplicaciones de sensores blandos industriales basados en datos. Ciencia E Ingeniería Neogranadina, 32(1), 59–70. https://doi.org/10.18359/rcin.5644

# %% [markdown]
# **Pasos**
#
#
# *   Abrir los datos contenidos en el GitHub con nombre dataset_distill.csv
#
# *   Mostrar las primeras 5 filas
# *  Identificar el nombre de las columnas

# %%
import pandas as pd

ruta="https://raw.githubusercontent.com/marinlopabi/TEMAS_SELECTOS-_DE_PROCESOS_QUIMICOS-ANALISIS_DE_DATOS_CON-_PYHTON-26P/refs/heads/main/ARCHIVOS/dataset_distill.csv"
df = pd.read_csv(ruta, sep=";") #La liga se debe de obtener en "crudo" o no agarrara y si solo copias el link de otra parte, tampoco agarrara
df.head()
# Out:
#    Pressure      T1      T2      T3      T4      T5      T6      T7      T8  \
# 0      1.01  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54
# 1      1.01  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43
# 2      1.01  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37
# 3      1.01  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34
# 4      1.01  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31
#
#        T9  ...     T11     T12     T13     T14    L     V    D    B    F  \
# 0  351.78  ...  353.00  355.19  363.77  371.47  780  1040  260  340  600
# 1  351.66  ...  352.76  354.66  362.20  370.98  780  1040  260  340  600
# 2  351.58  ...  352.55  354.13  360.16  370.10  780  1040  260  340  600
# 3  351.53  ...  352.40  353.75  358.45  368.99  780  1040  260  340  600
# 4  351.49  ...  352.30  353.50  357.23  367.81  780  1040  260  340  600
#
#    Ethanol concentration
# 0                0.82076
# ...

# %%
df.columns # te arroja los nombres de las columnas
# Out:
# Index(['Pressure', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10',
#        'T11', 'T12', 'T13', 'T14', 'L', 'V', 'D', 'B', 'F',
#        'Ethanol concentration'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.head() #Remplazo los espacios por gión bajo
# Out:
#    Pressure      T1      T2      T3      T4      T5      T6      T7      T8  \
# 0      1.01  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54
# 1      1.01  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43
# 2      1.01  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37
# 3      1.01  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34
# 4      1.01  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31
#
#        T9  ...     T11     T12     T13     T14    L     V    D    B    F  \
# 0  351.78  ...  353.00  355.19  363.77  371.47  780  1040  260  340  600
# 1  351.66  ...  352.76  354.66  362.20  370.98  780  1040  260  340  600
# 2  351.58  ...  352.55  354.13  360.16  370.10  780  1040  260  340  600
# 3  351.53  ...  352.40  353.75  358.45  368.99  780  1040  260  340  600
# 4  351.49  ...  352.30  353.50  357.23  367.81  780  1040  260  340  600
#
#    Ethanol_concentration
# 0                0.82076
# ...

# %%
df.columns
# Out:
# Index(['Pressure', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10',
#        'T11', 'T12', 'T13', 'T14', 'L', 'V', 'D', 'B', 'F',
#        'Ethanol_concentration'],
#       dtype='object')

# %% [markdown]
# ## Variables del conjunto de datos - Columna de Destilación
#
#
# Equipo utilizado para separar los componentes de una mezcla líquida mediante diferencias en sus puntos de ebullición.
#
#
#
#
#
# ![Captura de pantalla 2026-07-12 162427.png](data:image/png;base64,...)

# %%
df.describe()
# Out:
#            Pressure           T1           T2           T3           T4  \
# count  4.408000e+03  4408.000000  4408.000000  4408.000000  4408.000000
# mean   1.010000e+00   351.029049   351.409363   352.066202   352.828578
# std    1.141439e-13     0.334105     1.125225     2.671189     3.788418
# min    1.010000e+00   350.760000   350.770000   350.770000   350.790000
# 25%    1.010000e+00   350.820000   350.860000   350.900000   350.950000
# 50%    1.010000e+00   350.900000   350.990000   351.100000   351.260000
# 75%    1.010000e+00   351.080000   351.390000   351.822500   352.410000
# max    1.010000e+00   352.320000   356.030000   364.970000   368.600000
#
#                 T5           T6           T7           T8           T9  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000
# mean    353.910204   355.214270   356.453975   357.539902   358.484004
# std       4.986453     6.251028     7.119853     7.620257     7.882159
# ...

# %%
df.dtypes # Se observa que en la tabla anterior no aparecian la columna de Ly y V porque son reconocidas como objeto
# Out:
# Pressure                 float64
# T1                       float64
# T2                       float64
# T3                       float64
# T4                       float64
# T5                       float64
# T6                       float64
# T7                       float64
# T8                       float64
# T9                       float64
# T10                      float64
# T11                      float64
# T12                      float64
# T13                      float64
# T14                      float64
# L                         object
# V                         object
# D                          int64
# B                          int64
# F                          int64
# Ethanol_concentration    float64
# dtype: object

# %%
df["L"] = pd.to_numeric(df["L"], errors="coerce") # Los convirtio en númerico
df["V"] = pd.to_numeric(df["V"], errors="coerce")

# %%
df.describe()
# Out:
#            Pressure           T1           T2           T3           T4  \
# count  4.408000e+03  4408.000000  4408.000000  4408.000000  4408.000000
# mean   1.010000e+00   351.029049   351.409363   352.066202   352.828578
# std    1.141439e-13     0.334105     1.125225     2.671189     3.788418
# min    1.010000e+00   350.760000   350.770000   350.770000   350.790000
# 25%    1.010000e+00   350.820000   350.860000   350.900000   350.950000
# 50%    1.010000e+00   350.900000   350.990000   351.100000   351.260000
# 75%    1.010000e+00   351.080000   351.390000   351.822500   352.410000
# max    1.010000e+00   352.320000   356.030000   364.970000   368.600000
#
#                 T5           T6           T7           T8           T9  ...  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000  ...
# mean    353.910204   355.214270   356.453975   357.539902   358.484004  ...
# std       4.986453     6.251028     7.119853     7.620257     7.882159  ...
# ...

# %%
pd.set_option("display.max_columns", None) # Solo cambia la forma en que se visualizción de los datos.
df.describe()
# Out:
#            Pressure           T1           T2           T3           T4  \
# count  4.408000e+03  4408.000000  4408.000000  4408.000000  4408.000000
# mean   1.010000e+00   351.029049   351.409363   352.066202   352.828578
# std    1.141439e-13     0.334105     1.125225     2.671189     3.788418
# min    1.010000e+00   350.760000   350.770000   350.770000   350.790000
# 25%    1.010000e+00   350.820000   350.860000   350.900000   350.950000
# 50%    1.010000e+00   350.900000   350.990000   351.100000   351.260000
# 75%    1.010000e+00   351.080000   351.390000   351.822500   352.410000
# max    1.010000e+00   352.320000   356.030000   364.970000   368.600000
#
#                 T5           T6           T7           T8           T9  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000
# mean    353.910204   355.214270   356.453975   357.539902   358.484004
# std       4.986453     6.251028     7.119853     7.620257     7.882159
# ...

# %%
df.describe().style.format("{:.4f}") # Todos los números se muestran con solo 4 decimales
# Out:
# <style type="text/css">
# </style>
# <table id="T_2dd65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dd65_level0_col0" class="col_heading level0 col0" >Pressure</th>
#       <th id="T_2dd65_level0_col1" class="col_heading level0 col1" >T1</th>
#       <th id="T_2dd65_level0_col2" class="col_heading level0 col2" >T2</th>
#       <th id="T_2dd65_level0_col3" class="col_heading level0 col3" >T3</th>
#       <th id="T_2dd65_level0_col4" class="col_heading level0 col4" >T4</th>
#       <th id="T_2dd65_level0_col5" class="col_heading level0 col5" >T5</th>
#       <th id="T_2dd65_level0_col6" class="col_heading level0 col6" >T6</th>
#       <th id="T_2dd65_level0_col7" class="col_heading level0 col7" >T7</th>
#       <th id="T_2dd65_level0_col8" class="col_heading level0 col8" >T8</th>
#       <th id="T_2dd65_level0_col9" class="col_heading level0 col9" >T9</th>
# ...

# %% [markdown]
# ### **Ejercicio 2.**
#
# Armar un nuevo dataframe con los valores correspondientes con las temperaturas.

# %%
tem=df[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10', 'T11', 'T12','T13', 'T14']]
tem.head()
# Out:
#        T1      T2      T3      T4      T5      T6      T7      T8      T9  \
# 0  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54  351.78
# 1  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43  351.66
# 2  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37  351.58
# 3  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34  351.53
# 4  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31  351.49
#
#       T10     T11     T12     T13     T14
# 0  352.18  353.00  355.19  363.77  371.47
# 1  352.03  352.76  354.66  362.20  370.98
# 2  351.91  352.55  354.13  360.16  370.10
# 3  351.83  352.40  353.75  358.45  368.99
# 4  351.78  352.30  353.50  357.23  367.81

# %% [markdown]
# ## Asimetría
# **Coeficiente de asimetría de Fisher**
#
# El coeficiente de asimetría de Fisher es un coeficiente que permite calcular la asimetría de una distribución.
# Es decir, el coeficiente de asimetría sirve para determinar si una función es asimétrica positiva, asimétrica negativa o simétrica.
#
# Dada una muestra
#
#  {$ x1, x2,......,xn$},
#
# la fórmula del coeficiente de asimetría de Fisher es:
#
# ![Captura de pantalla 2026-07-12 165104.png](data:image/png;base64,...)
#
#
# Donde x y s son la media y la desviación estándar muestrales.
#
#  y1 >0 la distribución es asimétrica positiva. (cola a la derecha)
#  y1 <0 la distribución es asimétrica negativa. (cola a la izquierda)
#  ![Captura de pantalla 2026-07-12 165251.png](data:image/png;base64,...)

# %%
asimetria= tem.skew() # Para medir el grado y dirección de la asimetría, el número indica la dirección, es decir si es asimétrico o simétrico

print("\nAsimetría de Fisher:\n")
print(asimetria)
# Out:
# Asimetría de Fisher:
#
# T1     2.492693
# T2     3.072963
# T3     3.372123
# T4     2.757204
# T5     1.929362
# T6     1.453837
# T7     1.103980
# T8     0.833737
# T9     0.620700
# T10    0.461485
# T11    0.340554
# T12    0.237096
# T13   -0.232901
# T14   -0.786807
# dtype: float64

# %% [markdown]
# **Curtosis (Kurtosis)**
#
# La curtosis (Kurtosis) describe el grado en que las colas de una distribución difieren de las colas de una distribución normal.
# En otras palabras, mide qué tan afilada o achatada es la distribución en comparación con la normal.
#
# Python (a través de pandas, numpy y scipy) calcula la curtosis de Fisher, también conocida como exceso de curtosis, mediante la siguiente fórmula:
#
# ![Captura de pantalla 2026-07-12 165504.png](data:image/png;base64,...)
#
# Donde:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Interpretación del coeficiente de curtosis en Python
# ![Captura de pantalla 2026-07-12 165753.png](data:image/png;base64,...)
#
# En esta definición, la distribución normal tiene ( K = 0 ).
#
# ---------------
#
# Forma general de las distribuciones según su curtosis:
#
# **Leptocúrtica** → colas más gruesas (valores extremos más probables).
#
# **Mesocúrtica** → comportamiento normal.
#
# **Platicúrtica** → colas más ligeras (valores extremos menos probables).

# %% [markdown]
# ![Captura de pantalla 2026-07-12 171135.png](data:image/png;base64,...)

# %%
curtosis = tem.kurt() # Te ayuda a determinar el tipo de distribución de cada Temperatura  mesocúrtica (curtosis= 0), Leptocúrtica (curtosis > 0) y Platicúrtica (curtosis <0)

print("\nCurtosis de Fisher:\n")
print(curtosis)
# Out:
# Curtosis de Fisher:
#
# T1      6.116531
# T2      8.893402
# T3     11.176225
# T4      7.216824
# T5      2.512210
# T6      0.679761
# T7     -0.326081
# T8     -0.907161
# T9     -1.250669
# T10    -1.442167
# T11    -1.534859
# T12    -1.579903
# T13    -1.851379
# T14    -0.956866
# dtype: float64

# %%
import matplotlib.pyplot as plt

tem.hist(bins=20, figsize=(14,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio. Histograma Completo**

# %%
# 1. Calcular curtosis de Fisher
curtosis = tem.kurt()
# 2. Crear los histogramas
columnas = tem.columns
plt.figure(figsize=(15, 16))

for i, col in enumerate(columnas, 1):
    plt.subplot(4, 4, i)  # 4 filas, 4 columnas de gráficos
    plt.hist(tem[col], bins=20, color='pink', edgecolor='brown')
    plt.title(f"{col}\nCurtosis: {curtosis[col]:.2f}", fontsize=12)
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
#plt.suptitle("Distribución de temperaturas y su curtosis (Fisher)", fontsize=16)
plt.tight_layout()
#plt.savefig("histogramas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
cols_num = tem.select_dtypes(include="number") # Para obtener gráfica de caja de bigotes
cols_num.plot(kind="box", figsize=(14,6), grid=True)

plt.xticks(rotation=45, ha="right")
plt.ylabel("Temperatura (K)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Análisis Estadísticos parte 2.

# %% [markdown]
# **Ejercicio:**
#
# * Abrir los datos contenidos en el GitHub con nombre contam2022.csv
#
# * Mostrar las primeras 10 filas
# * Identificar el nombre de las columnas

# %%
import pandas as pd

ruta="https://raw.githubusercontent.com/marinlopabi/TEMAS_SELECTOS-_DE_PROCESOS_QUIMICOS-ANALISIS_DE_DATOS_CON-_PYHTON-26P/refs/heads/main/ARCHIVOS/contam2022.csv"
df = pd.read_csv(ruta)
df.head(10)
# Out:
#         Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 0  2022-01-01     36.916667                  6.333333
# 1  2022-01-02     17.250000                  7.750000
# 2  2022-01-03     24.083333                  7.833333
# 3  2022-01-04     27.583333                 27.416667
# 4  2022-01-05     30.875000                 12.833333
# 5  2022-01-06     25.583333                  8.916667
# 6  2022-01-07     12.333333                  7.833333
# 7  2022-01-08     22.583333                  6.500000
# 8  2022-01-09     24.708333                  4.500000
# 9  2022-01-10     21.500000                  7.000000
#
#    Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 0                    22.458333                   10.208333   106.916667
# 1                    15.833333                    9.500000    97.875000
# 2                    17.875000                    5.041667    61.958333
# 3                    27.125000                    8.250000    91.333333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Fecha                        365 non-null    object
#  1   Centro Ozono                 365 non-null    float64
#  2   Centro diÛxido de azufre     365 non-null    float64
#  3   Centro diÛxido de nitrÛgeno  365 non-null    float64
#  4   Centro monÛxido de carbono   365 non-null    float64
#  5   Centro PM10                  365 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.2+ KB

# %%
df.columns
# Out:
# Index(['Fecha', 'Centro Ozono', 'Centro diÛxido de azufre',
#        'Centro diÛxido de nitrÛgeno', 'Centro monÛxido de carbono',
#        'Centro PM10'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.replace("Centro Ozono", "Ozono")
df.head()
# Out:
#         Fecha      Ozono  Centro diÛxido de azufre  \
# 0  2022-01-01  36.916667                  6.333333
# 1  2022-01-02  17.250000                  7.750000
# 2  2022-01-03  24.083333                  7.833333
# 3  2022-01-04  27.583333                 27.416667
# 4  2022-01-05  30.875000                 12.833333
#
#    Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 0                    22.458333                   10.208333   106.916667
# 1                    15.833333                    9.500000    97.875000
# 2                    17.875000                    5.041667    61.958333
# 3                    27.125000                    8.250000    91.333333
# 4                    25.791667                    9.791667    94.000000

# %%
df.columns = df.columns.str.strip().str.replace("Centro Ozono", "ozono")
df.columns = df.columns.str.strip().str.replace("Centro diÛxido de azufre", "dioxido de S")
df.columns = df.columns.str.strip().str.replace("Centro diÛxido de nitrÛgeno", "dioxido de N")
df.columns = df.columns.str.strip().str.replace("Centro monÛxido de carbono", "monoxido")
df.columns = df.columns.str.strip().str.replace("Centro PM10", "PM10")
df.head() #Cambiamos los nombres de las columnas
# Out:
#         Fecha      Ozono  dioxido de S  dioxido de N   monoxido        PM10
# 0  2022-01-01  36.916667      6.333333     22.458333  10.208333  106.916667
# 1  2022-01-02  17.250000      7.750000     15.833333   9.500000   97.875000
# 2  2022-01-03  24.083333      7.833333     17.875000   5.041667   61.958333
# 3  2022-01-04  27.583333     27.416667     27.125000   8.250000   91.333333
# 4  2022-01-05  30.875000     12.833333     25.791667   9.791667   94.000000

# %%
df.columns
# Out:
# Index(['Fecha', 'Ozono', 'dioxido de S', 'dioxido de N', 'monoxido', 'PM10'], dtype='object')

# %%
df = df.rename(columns={
    "Ozono": "O3",
    "dioxido de S": "SO2",
    "dioxido de N": "NO2",
    "monoxido": "CO",
    "PM10": "PM10"
})

df.columns
# Out:
# Index(['Fecha', 'O3', 'SO2', 'NO2', 'CO', 'PM10'], dtype='object')

# %%
print(df)
# Out:
#           Fecha         O3        SO2        NO2         CO        PM10
# 0    2022-01-01  36.916667   6.333333  22.458333  10.208333  106.916667
# 1    2022-01-02  17.250000   7.750000  15.833333   9.500000   97.875000
# 2    2022-01-03  24.083333   7.833333  17.875000   5.041667   61.958333
# 3    2022-01-04  27.583333  27.416667  27.125000   8.250000   91.333333
# 4    2022-01-05  30.875000  12.833333  25.791667   9.791667   94.000000
# ..          ...        ...        ...        ...        ...         ...
# 360  2022-12-27  19.041667   5.750000  18.541667   5.583333   39.500000
# 361  2022-12-28  17.041667  11.000000  19.125000   8.583333   53.666667
# 362  2022-12-29  14.083333   4.750000  16.791667   7.625000   42.416667
# 363  2022-12-30  12.416667   4.916667  17.625000  10.166667   45.500000
# 364  2022-12-31  13.291667   2.833333  12.666667   5.541667   37.583333
#
# [365 rows x 6 columns]

# %%
df = df.set_index("Fecha") #Se agrego fecha como un nueo indice
df
# Out:
#                    O3        SO2        NO2         CO        PM10
# Fecha
# 2022-01-01  36.916667   6.333333  22.458333  10.208333  106.916667
# 2022-01-02  17.250000   7.750000  15.833333   9.500000   97.875000
# 2022-01-03  24.083333   7.833333  17.875000   5.041667   61.958333
# 2022-01-04  27.583333  27.416667  27.125000   8.250000   91.333333
# 2022-01-05  30.875000  12.833333  25.791667   9.791667   94.000000
# ...               ...        ...        ...        ...         ...
# 2022-12-27  19.041667   5.750000  18.541667   5.583333   39.500000
# 2022-12-28  17.041667  11.000000  19.125000   8.583333   53.666667
# 2022-12-29  14.083333   4.750000  16.791667   7.625000   42.416667
# 2022-12-30  12.416667   4.916667  17.625000  10.166667   45.500000
# 2022-12-31  13.291667   2.833333  12.666667   5.541667   37.583333
#
# [365 rows x 5 columns]

# %% [markdown]
# ## Estadistica descriptiva básica.

# %%
df.describe()
# Out:
#                O3         SO2         NO2          CO        PM10
# count  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    27.238470    7.128311   15.446575    5.365868   49.600000
# std     10.683100    5.100674    3.789316    1.750875   18.261962
# min      9.625000    2.000000    7.458333    2.208333   15.125000
# 25%     18.666667    4.000000   12.500000    4.041667   35.583333
# 50%     25.708333    5.666667   15.250000    5.083333   48.000000
# 75%     33.916667    8.416667   17.875000    6.291667   61.250000
# max     67.000000   34.416667   29.666667   12.000000  106.916667

# %% [markdown]
# # Correlación
#
# La correlación mide qué tan relacionadas están dos variables numéricas y cómo cambia una cuando cambia la otra.
#
# * Si al aumentar X, también tiende a aumentar Y → correlación positiva.
#
# * Si al aumentar X, Y tiende a disminuir → correlación negativa.
#
# * Si no hay un patrón claro de cambio conjunto → correlación cercana a 0.
#
# La correlación no implica causalidad: que dos variables se muevan juntas no significa que una cause a la otra.
#
#
# ![Captura de pantalla 2026-07-12 190343.png](data:image/png;base64,...)

# %% [markdown]
# ## a. Coeficiente de correlación de Pearson
#
# El coeficiente de correlación de Pearson (r) mide la fuerza y dirección de la relación lineal entre dos variables cuantitativas.
# Su valor siempre se encuentra en el rango -1 a 1.
#
# ![Captura de pantalla 2026-07-12 190401.png](data:image/png;base64,...)
#
#
# donde:
#
# ![Captura de pantalla 2026-07-12 190409.png](data:image/png;base64,...)

# %% [markdown]
# **Interpretación**
#
# ![Captura de pantalla 2026-07-12 190422.png](data:image/png;base64,...)
#
#
# ![Captura de pantalla 2026-07-12 190333.png](data:image/png;base64,...)

# %% [markdown]
# ### Supuestos del Coeficiente de Correlación de Pearson
# Para que el resultado del coeficiente de Pearson sea confiable, se deben cumplir ciertas condiciones o supuestos estadísticos.
# Estos aseguran que el valor de ( r ) refleje correctamente la relación entre las variables.
#
#  1. **Nivel de medición**
#
# Las variables deben ser numéricas y continuas (por ejemplo: temperatura, presión, concentración, altura, peso).
# Esto significa que deben poder medirse en una escala con valores reales, no solo categorías o rangos.
#
# 2. **Datos pareados**
#
# Cada observación debe tener un par de valores (xi, yi).
# Es decir, los datos de las dos variables deben pertenecer al mismo caso o experimento.
# Si falta un dato en alguna de las dos variables, esa observación no debe usarse en el cálculo.
#
# 3. **Normalidad bivariada**
#
# Los datos de ambas variables deben seguir una distribución normal conjunta.
#
# 4. **Relación lineal**
#
# El coeficiente de Pearson solo mide relaciones lineales.
# Esto significa que los puntos deben poder aproximarse por una línea recta.
# Si la relación tiene forma de curva (por ejemplo, parabólica), Pearson no es el método adecuado.
#
# 5. **Homocedasticidad**
#
# La dispersión de los puntos debe ser similar en todo el rango de valores.
# La varianza (dispersión de los datos) es constante en todas las observaciones de un conjunto de datos. Si la dispersión cambia mucho, la correlación puede ser engañosa.

# %% [markdown]
# **Python** (a través de pandas, numpy o scipy) utiliza por defecto la correlación de Pearson cuando aplicas:

# %% [markdown]
# Para calcular correlción entre todas las columnas númericas se utiliza:
# * **df.corr(method="pearson")**
#
# Para calcular correlación entre dos variables específicas se utiliza:
# * **df["x"].corr(df["Y"])**

# %%
import pandas as pd
df.corr(method='pearson')
# Out:
#             O3       SO2       NO2        CO      PM10
# O3    1.000000  0.101920  0.142250 -0.003331  0.481932
# SO2   0.101920  1.000000  0.310672  0.180158  0.456039
# NO2   0.142250  0.310672  1.000000  0.844692  0.626440
# CO   -0.003331  0.180158  0.844692  1.000000  0.559163
# PM10  0.481932  0.456039  0.626440  0.559163  1.000000

# %%
df['CO'].corr(df['NO2'])
# Out:
# np.float64(0.8446921809216084)

# %% [markdown]
# ### 1. Gráfica de Correlación

# %%
import matplotlib.pyplot as plt #Biblioteca para crear gráficos

# %%
corr = df.corr(method='pearson') # calcula la matriz de correlación entre todas las columnas

plt.figure(figsize=(8,6)) # figsize define el tamaño del gráfico (ancho,alto)
plt.imshow(corr, cmap='coolwarm', interpolation='none') #imshow = mostrar imagen, cmap = coolwarm significa mapa de colores
plt.colorbar()
# color azul = correlcion negativa, blanco = correlación cercana a 0 y Rojo= correlción positiva / none es para no suavizar los colores
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45) #etiquetas del eje X, lo de 45 es para rotar y no se encimen las etiquetas
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Matriz de Correlación (Pearson)") # Se coloca el titulo de la gráfica
plt.show()

# %%
import seaborn as sns #gráficas más profesionales de manera muy sencilla.

# %% [markdown]
# * **scatterplot:** puntos para ver relaciones
#
# * **lineplot:** líneas para tendencias
#
# * **barplot:** barras para comparar categorías
#
# * **histplot:** distribución de datos
#
# * **boxplot:** cajas para ver rangos y valores atípicos
#
# * **heatmap**: mapas de calor para matrices

# %%
corr = df.corr(method='pearson')
plt.figure(figsize=(8,6))
sns.heatmap(corr,
            annot=True,        # muestra valores
            cmap='coolwarm',   # paleta
            fmt=".2f",         # 2 decimales
            linewidths=0.5)
plt.title("Matriz de Correlación (Pearson)")
plt.show()

# %% [markdown]
# #Prueba de Normalidad de Shapiro–Wilk
#
# La prueba de **Shapiro–Wilk **se utiliza para evaluar si un conjunto de datos proviene de una distribución normal.
# Es una de las pruebas más utilizadas y confiables para comprobar la normalidad, especialmente cuando se trabaja con **muestras pequeñas o moderadas** (n < 2000).

# %% [markdown]
# ## Hipótesis del test
#
# Esta prueba parte de una hipótesis nula que afirma que la muestra sí proviene de una distribución normal.
#
# * **Hipótesis nula (H₀)**:
# La muestra proviene de una distribución normal.
# Se acepta H₀ si el valor p es mayor que 0.05.
#
# * **Hipótesis alternativa (H₁)**:
# La muestra no proviene de una distribución normal.
# Se rechaza H₀ (y se acepta H₁) si el valor p es menor que 0.05.

# %% [markdown]
# **a. Interpretaciones del valor de p**
#
#
# ![Captura de pantalla 2026-07-12 195459.png](data:image/png;base64,...)

# %%
from scipy.stats import shapiro

for col in df.columns:
    stat, p = shapiro(df[col])
    print(f"{col}: Estadístico = {stat:.3f}, p-valor = {p:.8f}")
# Out:
# O3: Estadístico = 0.946, p-valor = 0.00000000
# SO2: Estadístico = 0.791, p-valor = 0.00000000
# NO2: Estadístico = 0.981, p-valor = 0.00010877
# CO: Estadístico = 0.941, p-valor = 0.00000000
# PM10: Estadístico = 0.980, p-valor = 0.00005488

# %% [markdown]
# Como los datos no cumplen con la normalidad, usaremos otra prueba de correlación.

# %% [markdown]
# ## Correlación de Spearman
#
# Cuando los datos **no cumplen el supuesto de normalidad**, no es adecuado usar la correlación de Pearson, ya que esta se basa en distribuciones normales y relaciones lineales.
# En estos casos, se recomienda aplicar la correlación de Spearman, también conocida como Rho de Spearman (ρ).
#
# -------
#
# La correlación de Spearman evalúa **la fuerza y dirección de la relación monótona **(creciente o decreciente) entre dos variables numéricas u ordinales.
# A diferencia de Pearson, no requiere que los datos sean normales ni que la relación sea lineal.
#
# Spearman convierte los valores de las variables en rangos (posiciones ordenadas) y calcula la correlación entre esos rangos.
#
# ![Captura de pantalla 2026-07-12 195155.png](data:image/png;base64,...)
#
# donde:
# * di es la diferencia entre los rangos de las observaciones de (X) y (Y)
#
# * n  es el número de pares de observaciones.
#
# El resultado p, siempre se encuentra entre -1 y 1

# %% [markdown]
# **a. Interpretación del Valor de p**
#
#
# ![Captura de pantalla 2026-07-12 194639.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio de cálculo manual del coeficiente de Spearman**
#
# Ontener el coefciente de correlación de Spearman para los siguientes datos.
# ![Captura de pantalla 2026-07-12 194629.png](data:image/png;base64,...)

# %% [markdown]
# Primero se realizara de manera manual y después deberan resolverlo en Python usando operadores aritméticos.
#
# Realizar una interpretación del resultado.
#
# ![Captura de pantalla 2026-07-12 195935.png](data:image/png;base64,...)
#
# **Procedimiento**
#
# ![Captura de pantalla 2026-07-12 195944.png](data:image/png;base64,...)
